# %%
import random
import pandas as pd

def generate_fake_data(num_observations.num_visits):
    min_age, max_age = 18, 50
    min_density, max_density = 1, 100
    min_diameter, max_diameter = 0.1, 0.5
    min_texture, max_texture = 1, 10
    min_porosity, max_porosity = 1, 5
    min_elasticity, max_elasticity = 1, 10
    min_strength, max_strength = 1, 10
    min_shine, max_shine = 1, 10
    min_smoothness, max_smoothness = 1, 10
    min_growth_rate, max_growth_rate = 0.1, 1.0
    min_volume, max_volume = 50, 200

    data = []
    for _ in range(num_observations):
        observations = []
        for visit in range(num_visits):
            age = random.randint(min_age, max_age)
            density = random.randint(min_density, max_density)
            diameter = round(random.uniform(min_diameter, max_diameter), 2)
            texture = random.randint(min_texture, max_texture)
            porosity = random.randint(min_porosity, max_porosity)
            elasticity = random.randint(min_elasticity, max_elasticity)
            strength = random.randint(min_strength, max_strength)
            shine = random.randint(min_shine, max_shine)
            smoothness = random.randint(min_smoothness, max_smoothness)
            growth_rate = round(random.uniform(min_growth_rate, max_growth_rate), 2)
            volume = random.randint(min_volume, max_volume)
            
       

        age_after = age_before + 1
        density_after = density_before + 1
        diameter_after = round(min(max_diameter, diameter_before + 0.01), 2)
        texture_after = texture_before + 1
        porosity_after = porosity_before + 1
        elasticity_after = elasticity_before + 1
        strength_after = strength_before + 1
        shine_after = shine_before + 1
        smoothness_after = smoothness_before + 1
        growth_rate_after = round(min(max_growth_rate, growth_rate_before + 0.01), 2)
        volume_after = volume_before + 10

        # Create a dictionary for before and after observations of each individual
        observation_before = {
            'Age': age_before,
            'Hair Density': density_before,
            'Hair Diameter': diameter_before,
            'Texture': texture_before,
            'Porosity': porosity_before,
            'Elasticity': elasticity_before,
            'Strength': strength_before,
            'Shine': shine_before,
            'Smoothness': smoothness_before,
            'Growth Rate': growth_rate_before,
            'Volume': volume_before,
            
        }

        observation_after = {
            'Age': age_after,
            'Hair Density': density_after,
            'Hair Diameter': diameter_after,
            'Texture': texture_after,
            'Porosity': porosity_after,
            'Elasticity': elasticity_after,
            'Strength': strength_after,
            'Shine': shine_after,
            'Smoothness': smoothness_after,
            'Growth Rate': growth_rate_after,
            'Volume': volume_after,
            'Visit': 'After'
        }

        data.append(observation_before)
        data.append(observation_after)

    return data

num_observations = 50  # You can change this number to generate more or fewer observations
fake_data = generate_fake_data(num_observations)

# Convert the list of dictionaries to a pandas DataFrame with multi-index
df = pd.DataFrame(fake_data)
df.set_index(['Visit', df.index], inplace=True)

print(df.head())  # Display the first few rows of the generated dataset

# %%
import random
import pandas as pd

def generate_fake_data(num_observations, num_visits):
    min_age, max_age = 18, 50
    min_density, max_density = 1, 100
    min_diameter, max_diameter = 0.1, 0.5
    min_texture, max_texture = 1, 10
    min_porosity, max_porosity = 1, 5
    min_elasticity, max_elasticity = 1, 10
    min_strength, max_strength = 1, 10
    min_shine, max_shine = 1, 10
    min_smoothness, max_smoothness = 1, 10
    min_growth_rate, max_growth_rate = 0.1, 1.0
    min_volume, max_volume = 50, 200

    data = []
    for _ in range(num_observations):
        observations = []
        for visit in range(num_visits):
            age = random.randint(min_age, max_age)
            density = random.randint(min_density, max_density)
            diameter = round(random.uniform(min_diameter, max_diameter), 2)
            texture = random.randint(min_texture, max_texture)
            porosity = random.randint(min_porosity, max_porosity)
            elasticity = random.randint(min_elasticity, max_elasticity)
            strength = random.randint(min_strength, max_strength)
            shine = random.randint(min_shine, max_shine)
            smoothness = random.randint(min_smoothness, max_smoothness)
            growth_rate = round(random.uniform(min_growth_rate, max_growth_rate), 2)
            volume = random.randint(min_volume, max_volume)

            observation = {
                'Age': age,
                'Hair Density': density,
                'Hair Diameter': diameter,
                'Texture': texture,
                'Porosity': porosity,
                'Elasticity': elasticity,
                'Strength': strength,
                'Shine': shine,
                'Smoothness': smoothness,
                'Growth Rate': growth_rate,
                'Volume': volume,
                'Visit': f'Visit {visit + 1}'
            }
            observations.append(observation)

        data.extend(observations)

    return data

num_observations = 50  # You can change this number to generate more or fewer individuals
num_visits = 3  # You can change this number to decide the number of visits for each individual
fake_data = generate_fake_data(num_observations, num_visits)

# Convert the list of dictionaries to a pandas DataFrame with multi-index
df = pd.DataFrame(fake_data)
df.set_index(['Visit', df.index], inplace=True)

print(df.head())  # Display the first few rows of the generated dataset
# Out:
#            Age  Hair Density  Hair Diameter  Texture  Porosity  Elasticity  \
# Visit
# Visit 1 0   44            59           0.41       10         3           3
# Visit 2 1   36            77           0.22        3         3           7
# Visit 3 2   33            91           0.33        8         5           4
# Visit 1 3   20             3           0.45        6         5           3
# Visit 2 4   31            68           0.30        4         2           3
#
#            Strength  Shine  Smoothness  Growth Rate  Volume
# Visit
# Visit 1 0         6      9           5         0.93      72
# Visit 2 1         9      7          10         0.68     153
# Visit 3 2         7     10           6         0.61     192
# Visit 1 3        10      9           5         0.32     145
# Visit 2 4         7      9          10         0.76      85

# %%
import random
import pandas as pd

def generate_fake_data(num_observations, num_visits):
    min_age, max_age = 18, 50
    min_density, max_density = 1, 100
    min_diameter, max_diameter = 0.1, 0.5
    min_texture, max_texture = 1, 10
    min_porosity, max_porosity = 1, 5
    min_elasticity, max_elasticity = 1, 10
    min_strength, max_strength = 1, 10
    min_shine, max_shine = 1, 10
    min_smoothness, max_smoothness = 1, 10
    min_growth_rate, max_growth_rate = 0.1, 1.0
    min_volume, max_volume = 50, 200

    visits_data = {}
    for visit in range(num_visits):
        data = []
        for _ in range(num_observations):
            age = random.randint(min_age, max_age)
            density = random.randint(min_density, max_density)
            diameter = round(random.uniform(min_diameter, max_diameter), 2)
            texture = random.randint(min_texture, max_texture)
            porosity = random.randint(min_porosity, max_porosity)
            elasticity = random.randint(min_elasticity, max_elasticity)
            strength = random.randint(min_strength, max_strength)
            shine = random.randint(min_shine, max_shine)
            smoothness = random.randint(min_smoothness, max_smoothness)
            growth_rate = round(random.uniform(min_growth_rate, max_growth_rate), 2)
            volume = random.randint(min_volume, max_volume)

            observation = {
                'Age': age,
                'Hair Density': density,
                'Hair Diameter': diameter,
                'Texture': texture,
                'Porosity': porosity,
                'Elasticity': elasticity,
                'Strength': strength,
                'Shine': shine,
                'Smoothness': smoothness,
                'Growth Rate': growth_rate,
                'Volume': volume,
                'Visit': f'Visit {visit + 1}'
            }
            data.append(observation)

        visits_data[f'Visit {visit + 1}'] = data

    return visits_data

num_observations = 50  # You can change this number to generate more or fewer individuals
num_visits = 3  # You can change this number to decide the number of visits for each individual
visits_data = generate_fake_data(num_observations, num_visits)

# Create separate DataFrames for each visit
dfs = {visit: pd.DataFrame(data) for visit, data in visits_data.items()}

# Display the first few rows of each DataFrame
for visit, df in dfs.items():
    print(f"Visit: {visit}")
    print(df.head())
    print("\n")
# Create a list of DataFrames for each visit
dfs = [pd.DataFrame(data) for data in visits_data.values()]

# Concatenate DataFrames for each visit
combined_df = pd.concat(dfs, ignore_index=True)

# Save the combined data to a CSV file
file_name = "combined_data.csv"
combined_df.to_csv(file_name, index=False)
print(f"Total data saved to {file_name}.")
# Out:
# Visit: Visit 1
#    Age  Hair Density  Hair Diameter  Texture  Porosity  Elasticity  Strength  \
# 0   35             3           0.37        2         1           3         6
# 1   37            28           0.15        6         3           2         8
# 2   24            62           0.44        6         3           8         6
# 3   18            35           0.39        1         3           7         3
# 4   23            74           0.14        6         4           8         6
#
#    Shine  Smoothness  Growth Rate  Volume    Visit
# 0      1           2         0.94     151  Visit 1
# 1      5           7         0.19     200  Visit 1
# 2     10          10         0.57     142  Visit 1
# 3      6           3         0.88     171  Visit 1
# 4      2           1         0.58      93  Visit 1
#
#
# Visit: Visit 2
#    Age  Hair Density  Hair Diameter  Texture  Porosity  Elasticity  Strength  \
# 0   28            58           0.37        6         3           7         6
# ...

# %%
import random
import pandas as pd

def generate_fake_data(num_observations, num_visits):
    min_age, max_age = 18, 50
    min_density, max_density = 1, 100
    min_diameter, max_diameter = 0.1, 0.5
    min_texture, max_texture = 1, 10
    min_porosity, max_porosity = 1, 5
    min_elasticity, max_elasticity = 1, 10
    min_strength, max_strength = 1, 10
    min_shine, max_shine = 1, 10
    min_smoothness, max_smoothness = 1, 10
    min_growth_rate, max_growth_rate = 0.1, 1.0
    min_volume, max_volume = 50, 200
    variation_factor = 0.1  # Factor to control the amount of variation between visits

    visits_data = {}
    for visit in range(num_visits):
        data = []
        for _ in range(num_observations):
            age = random.randint(min_age, max_age)

            # Introduce variations based on the visit number
            if visit == 0:
                density = random.randint(min_density, max_density)
                diameter = round(random.uniform(min_diameter, max_diameter), 2)
                texture = random.randint(min_texture, max_texture)
                porosity = random.randint(min_porosity, max_porosity)
                elasticity = random.randint(min_elasticity, max_elasticity)
                strength = random.randint(min_strength, max_strength)
                shine = random.randint(min_shine, max_shine)
                smoothness = random.randint(min_smoothness, max_smoothness)
                growth_rate = round(random.uniform(min_growth_rate, max_growth_rate), 2)
                volume = random.randint(min_volume, max_volume)
            else:
                # Introduce variations from the previous visit if data is available
                if data:
                    prev_data = data[-1]
                    density = int(prev_data['Hair Density'] * (1 + random.uniform(-variation_factor, variation_factor)))
                    diameter = round(prev_data['Hair Diameter'] * (1 + random.uniform(-variation_factor, variation_factor)), 2)
                    texture = int(prev_data['Texture'] * (1 + random.uniform(-variation_factor, variation_factor)))
                    porosity = int(prev_data['Porosity'] * (1 + random.uniform(-variation_factor, variation_factor)))
                    elasticity = int(prev_data['Elasticity'] * (1 + random.uniform(-variation_factor, variation_factor)))
                    strength = int(prev_data['Strength'] * (1 + random.uniform(-variation_factor, variation_factor)))
                    shine = int(prev_data['Shine'] * (1 + random.uniform(-variation_factor, variation_factor)))
                    smoothness = int(prev_data['Smoothness'] * (1 + random.uniform(-variation_factor, variation_factor)))
                    growth_rate = round(prev_data['Growth Rate'] * (1 + random.uniform(-variation_factor, variation_factor)), 2)
                    volume = int(prev_data['Volume'] * (1 + random.uniform(-variation_factor, variation_factor)))
                else:
                    # For the first observation of subsequent visits, generate new random data
                    density = random.randint(min_density, max_density)
                    diameter = round(random.uniform(min_diameter, max_diameter), 2)
                    texture = random.randint(min_texture, max_texture)
                    porosity = random.randint(min_porosity, max_porosity)
                    elasticity = random.randint(min_elasticity, max_elasticity)
                    strength = random.randint(min_strength, max_strength)
                    shine = random.randint(min_shine, max_shine)
                    smoothness = random.randint(min_smoothness, max_smoothness)
                    growth_rate = round(random.uniform(min_growth_rate, max_growth_rate), 2)
                    volume = random.randint(min_volume, max_volume)

            observation = {
                'Age': age,
                'Hair Density': density,
                'Hair Diameter': diameter,
                'Texture': texture,
                'Porosity': porosity,
                'Elasticity': elasticity,
                'Strength': strength,
                'Shine': shine,
                'Smoothness': smoothness,
                'Growth Rate': growth_rate,
                'Volume': volume,
                'Visit': f'Visit {visit + 1}'
            }
            data.append(observation)

        visits_data[f'Visit {visit + 1}'] = data

    return visits_data

num_observations = 50  # You can change this number to generate more or fewer individuals
num_visits = 3  # You can change this number to decide the number of visits for each individual
visits_data = generate_fake_data(num_observations, num_visits)

# Create a list of DataFrames for each visit
dfs = [pd.DataFrame(data) for data in visits_data.values()]

# Concatenate DataFrames for each visit
combined_df = pd.concat(dfs, ignore_index=True)

# Save the combined data to a CSV file
file_name = "combined_data_with_variation.csv"
combined_df.to_csv(file_name, index=False)
print(f"Total data with variations saved to {file_name}.")
# Out:
# Total data with variations saved to combined_data_with_variation.csv.

# %%
import random
import pandas as pd

def generate_fake_data(num_observations, num_visits):
    min_age, max_age = 18, 50
    min_density, max_density = 1, 100
    min_diameter, max_diameter = 0.1, 0.5
    min_texture, max_texture = 1, 10
    min_porosity, max_porosity = 1, 5
    min_elasticity, max_elasticity = 1, 10
    min_strength, max_strength = 1, 10
    min_shine, max_shine = 1, 10
    min_smoothness, max_smoothness = 1, 10
    min_growth_rate, max_growth_rate = 0.1, 1.0
    min_volume, max_volume = 50, 200
    variation_factor = 0.1  # Factor to control the amount of variation between visits

    visits_data = {}
    for visit in range(num_visits):
        data = []
        for _ in range(num_observations):
            age = random.randint(min_age, max_age)

            # Introduce variations based on the visit number
            density = random.randint(int(min_density * (1 - variation_factor * visit)), int(max_density * (1 + variation_factor * visit)))
            diameter = round(random.uniform(min_diameter * (1 - variation_factor * visit), max_diameter * (1 + variation_factor * visit)), 2)
            texture = random.randint(int(min_texture * (1 - variation_factor * visit)), int(max_texture * (1 + variation_factor * visit)))
            porosity = random.randint(int(min_porosity * (1 - variation_factor * visit)), int(max_porosity * (1 + variation_factor * visit)))
            elasticity = random.randint(int(min_elasticity * (1 - variation_factor * visit)), int(max_elasticity * (1 + variation_factor * visit)))
            strength = random.randint(int(min_strength * (1 - variation_factor * visit)), int(max_strength * (1 + variation_factor * visit)))
            shine = random.randint(int(min_shine * (1 - variation_factor * visit)), int(max_shine * (1 + variation_factor * visit)))
            smoothness = random.randint(int(min_smoothness * (1 - variation_factor * visit)), int(max_smoothness * (1 + variation_factor * visit)))
            growth_rate = round(random.uniform(min_growth_rate * (1 - variation_factor * visit), max_growth_rate * (1 + variation_factor * visit)), 2)
            volume = random.randint(int(min_volume * (1 - variation_factor * visit)), int(max_volume * (1 + variation_factor * visit)))

            observation = {
                'Age': age,
                'Hair Density': density,
                'Hair Diameter': diameter,
                'Texture': texture,
                'Porosity': porosity,
                'Elasticity': elasticity,
                'Strength': strength,
                'Shine': shine,
                'Smoothness': smoothness,
                'Growth Rate': growth_rate,
                'Volume': volume,
                'Visit': f'Visit {visit + 1}'
            }
            data.append(observation)

        visits_data[f'Visit {visit + 1}'] = data

    return visits_data

num_observations = 50  # You can change this number to generate more or fewer individuals
num_visits = 3  # You can change this number to decide the number of visits for each individual
visits_data = generate_fake_data(num_observations, num_visits)

# Create a list of DataFrames for each visit
dfs = [pd.DataFrame(data) for data in visits_data.values()]

# Concatenate DataFrames for each visit
combined_df = pd.concat(dfs, ignore_index=True)

# Save the combined data to a CSV file
file_name = "combined_data_with_visit_variation.csv"
combined_df.to_csv(file_name, index=False)
print(f"Total data with visit variations saved to {file_name}.")
# Out:
# Total data with visit variations saved to combined_data_with_visit_variation.csv.

# %%
# Create a list of DataFrames for each visit
dfs = [pd.DataFrame(data) for data in visits_data.values()]

# Concatenate DataFrames for each visit
combined_df = pd.concat(dfs, ignore_index=True)

# Convert "Visit" labels to numeric values
combined_df['Visit'] = combined_df['Visit'].map(lambda x: int(x.split()[-1]))

# Save the combined data to a CSV file
file_name = "combined_data_with_visit_variation.csv"
combined_df.to_csv(file_name, index=False)
print(f"Total data with visit variations saved to {file_name}.")
# Provide a download link for the generated CSV file
download_link = f"<a href='{file_name}' download>Download the generated data as a CSV file</a>"
print(download_link)
# Out:
# Total data with visit variations saved to combined_data_with_visit_variation.csv.
# <a href='combined_data_with_visit_variation.csv' download>Download the generated data as a CSV file</a>

# %%
data=pd.read_csv("C:/Users/Janhavi/Downloads/combined_data_with_visit_variation.csv")

# %%
data
# Out:
#      Age  Hair Density  Hair Diameter  Texture  Porosity  Elasticity  \
# 0     44            17           0.29        7         1           7
# 1     44            30           0.46        8         2           9
# 2     44            58           0.38        3         5           4
# 3     22            31           0.17        5         4           3
# 4     46            92           0.43        6         3          10
# ..   ...           ...            ...      ...       ...         ...
# 145   28            11           0.28        3         4           0
# 146   25            97           0.45        1         1           9
# 147   21            36           0.30        8         1           3
# 148   42           108           0.40        7         3           7
# 149   20            59           0.30        5         4          12
#
#      Strength  Shine  Smoothness  Growth Rate  Volume  Visit
# 0           4      1           7         0.32     138      1
# ...

# %%
data.describe()
# Out:
#               Age  Hair Density  Hair Diameter     Texture    Porosity  \
# count  150.000000    150.000000     150.000000  150.000000  150.000000
# mean    33.540000     53.140000       0.320067    5.553333    2.946667
# std      9.439763     32.003362       0.135238    3.553119    1.760059
# min     18.000000      1.000000       0.080000    0.000000    0.000000
# 25%     25.000000     23.000000       0.192500    2.000000    1.000000
# 50%     34.000000     49.500000       0.320000    6.000000    3.000000
# 75%     42.000000     79.750000       0.440000    8.000000    4.000000
# max     50.000000    120.000000       0.580000   12.000000    6.000000
#
#        Elasticity    Strength       Shine  Smoothness  Growth Rate  \
# count  150.000000  150.000000  150.000000  150.000000   150.000000
# mean     5.800000    5.646667    5.773333    5.633333     0.583467
# std      3.270778    3.487536    3.350141    3.433777     0.307128
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 150 entries, 0 to 149
# Data columns (total 12 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Age            150 non-null    int64
#  1   Hair Density   150 non-null    int64
#  2   Hair Diameter  150 non-null    float64
#  3   Texture        150 non-null    int64
#  4   Porosity       150 non-null    int64
#  5   Elasticity     150 non-null    int64
#  6   Strength       150 non-null    int64
#  7   Shine          150 non-null    int64
#  8   Smoothness     150 non-null    int64
#  9   Growth Rate    150 non-null    float64
#  10  Volume         150 non-null    int64
#  11  Visit          150 non-null    int64
# dtypes: float64(2), int64(10)
# memory usage: 14.2 KB

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Box Plot for Hair Attributes by Visit
plt.figure(figsize=(10, 6))
plt.title("Box Plot for Hair Attributes by Visit")
sns.boxplot(x="Visit", y="Hair Density", data=combined_df)
plt.xlabel("Visit")
plt.ylabel("Hair Density")
plt.show()

# %%
# Histogram for Hair Diameter
plt.figure(figsize=(10, 6))
plt.title("Histogram for Hair Diameter")
plt.hist(combined_df['Hair Diameter'], bins=10, edgecolor='black')
plt.xlabel("Hair Diameter")
plt.ylabel("Frequency")
plt.show()

# %%
# Scatter Plot for Hair Volume vs. Hair Density
plt.figure(figsize=(10, 6))
plt.title("Scatter Plot for Hair Volume vs. Hair Density")
plt.scatter(combined_df['Hair Density'], combined_df['Volume'])
plt.xlabel("Hair Density")
plt.ylabel("Volume")
plt.show()

# %%
# Create a pivot table with mean hair density for each combination of 'Texture' and 'Porosity'
heatmap_data = combined_df.pivot_table(index='Texture', columns='Porosity', values='Hair Density', aggfunc='mean')

# Create the heatmap
plt.figure(figsize=(10, 8))
plt.title("Mean Hair Density by Texture and Porosity")
sns.heatmap(heatmap_data, annot=True, cmap='YlGnBu', fmt=".2f", linewidths=0.5)
plt.xlabel("Porosity")
plt.ylabel("Texture")
plt.show()

# %%
# Bar Plot for Hair Attributes Mean by Visit
plt.figure(figsize=(10, 6))
plt.title("Hair Attributes Mean by Visit")
sns.barplot(x="Visit", y="Hair Diameter", data=combined_df, ci=None)
plt.xlabel("Visit")
plt.ylabel("Hair Diameter Mean")
plt.show()
# Out:
# C:\Users\Janhavi\AppData\Local\Temp\ipykernel_4188\933993686.py:4: FutureWarning:
#
# The `ci` parameter is deprecated. Use `errorbar=None` for the same effect.
#
#   sns.barplot(x="Visit", y="Hair Diameter", data=combined_df, ci=None)

# %%
import random
import pandas as pd
import matplotlib.pyplot as plt

# Function to generate fake data for multiple visits
def generate_fake_data(num_visits):
    # ... (same as before) ...
    pass  # Add a pass statement to create an indented block

# The rest of the code remains the same as before...

# Create a list of DataFrames for each visit
dfs = [pd.DataFrame(data) for data in visits_data.values()]

# Concatenate DataFrames for each visit
combined_df = pd.concat(dfs, ignore_index=True)

# Convert "Visit" labels to numeric values
combined_df['Visit'] = combined_df['Visit'].map(lambda x: int(x.split()[-1]))

# Save the combined data to a CSV file
file_name = "combined_data_with_visit_variation.csv"
combined_df.to_csv(file_name, index=False)
print(f"Total data with visit variations saved to {file_name}.")

# Calculate the correlation coefficient between Volume and Shine
correlation_coefficient = combined_df['Volume'].corr(combined_df['Shine'])
print(f"Correlation Coefficient between Volume and Shine: {correlation_coefficient:.2f}")
# Out:
# Total data with visit variations saved to combined_data_with_visit_variation.csv.
# Correlation Coefficient between Volume and Shine: 0.13

# %%
import pandas as pd
from scipy.stats import f_oneway

# Load the data (make sure "Visit" column is in numeric format)
data = pd.read_csv("combined_data_with_visit_variation.csv")

# Separate data for each hair factor
hair_factors = ['Hair Density', 'Hair Diameter', 'Texture', 'Porosity', 'Elasticity',
                'Strength', 'Shine', 'Smoothness', 'Growth Rate', 'Volume']

for factor in hair_factors:
    # Perform ANOVA
    anova_result = f_oneway(*[data[data['Visit'] == i][factor] for i in range(1, num_visits + 1)])
    
    # Get the p-value
    p_value = anova_result.pvalue
    
    # Print the results
    print(f"Factor: {factor}")
    print("ANOVA p-value:", p_value)
    if p_value < 0.05:
        print("There is a significant difference between at least one pair of visits.")
    else:
        print("There is no significant difference between visits for this factor.")
    print("-" * 50)
# Out:
# Factor: Hair Density
# ANOVA p-value: 0.17578845386824118
# There is no significant difference between visits for this factor.
# --------------------------------------------------
# Factor: Hair Diameter
# ANOVA p-value: 0.10486168048036233
# There is no significant difference between visits for this factor.
# --------------------------------------------------
# Factor: Texture
# ANOVA p-value: 0.7719303363702841
# There is no significant difference between visits for this factor.
# --------------------------------------------------
# Factor: Porosity
# ANOVA p-value: 3.4773176071324926e-05
# There is a significant difference between at least one pair of visits.
# --------------------------------------------------
# Factor: Elasticity
# ANOVA p-value: 0.701184776800296
# There is no significant difference between visits for this factor.
# --------------------------------------------------
# Factor: Strength
# ANOVA p-value: 0.9929944730587602
# ...

# %%
pip install statsmodels
# Out:
# ...
# [notice] A new release of pip available: 22.3.1 -> 23.2.1
# [notice] To update, run: python.exe -m pip install --upgrade pip
# ...
#      ---------------------------------------- 9.2/9.2 MB 3.2 MB/s eta 0:00:00
# ...
#      -------------------------------------- 233.8/233.8 kB 1.3 MB/s eta 0:00:00
# ...

# %%
# Check normality for "Growth Rate" within each group (visit)
for visit in range(1, num_visits + 1):
    density_for_visit = combined_df[combined_df['Visit'] == visit]['Growth Rate']
    print(f'Normality Test for Growth Rate - Visit {visit}')
    print("Shapiro-Wilk Test p-value:", stats.shapiro(density_for_visit)[1])
    print("-" * 50)

# Check equal variance for "Growth Rate" across different groups (visits)
density_groups = [combined_df[combined_df['Visit'] == visit]['Growth Rate'] for visit in range(1, num_visits + 1)]
print("Equal Variance Test for Growth Rate")
print("Levene's Test p-value:", stats.levene(*density_groups)[1])
print("-" * 50)
# Out:
# Normality Test for Growth Rate - Visit 1
# Shapiro-Wilk Test p-value: 0.03222900256514549
# --------------------------------------------------
# Normality Test for Growth Rate - Visit 2
# Shapiro-Wilk Test p-value: 0.0007489869021810591
# --------------------------------------------------
# Normality Test for Growth Rate - Visit 3
# Shapiro-Wilk Test p-value: 0.01529432088136673
# --------------------------------------------------
# Equal Variance Test for Growth Rate
# Levene's Test p-value: 0.08229058030896902
# --------------------------------------------------
